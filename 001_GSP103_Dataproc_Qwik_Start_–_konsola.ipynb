# %% [markdown]
# [Dataproc: Qwik Start – konsola](https://www.cloudskillsboost.google/focuses/586?catalog_rank=%7B%22rank%22%3A2%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=23664769)

# %% [markdown]
# ![2023-05-05 11_47_49-Dataproc_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://spark.apache.org/

# https://hadoop.apache.org/

# %% [markdown]
# ![2023-05-05 12_00_36-Dataproc_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_00_17-Biblioteka API – Interfejsy API i us… – qwiklabs-gcp-01-30a… – Google Cloud Cons.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_02_22-Dataproc_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_03_04-Dataproc_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_04_00-Klastry – Dataproc – qwiklabs-gcp-01-30a… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_06_08-Dataproc_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_10_35-Tworzenie klastra Dataproc w Compute Engine – Dataproc – qwiklabs-gcp-01-30a… – .png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-05 12_09_29-Tworzenie klastra Dataproc w Compute Engine – Dataproc – qwiklabs-gcp-01-30a… – .png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 11_49_53-Utwórz klaster Dataproc w Compute Engine – Dataproc – qwiklabs-gcp-03-d9c… – Kon.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 12_00_09-Dataproc_ Qwik Start – konsola _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 11_51_13-Create a Dataproc cluster on Compute Engine – Dataproc – qwiklabs-gcp-03-d9c… – .png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 11_54_30-Submit a job – Dataproc – qwiklabs-gcp-03-d9c… – Google Cloud console.png](data:image/png;base64,...)
